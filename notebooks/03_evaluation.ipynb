# %% [markdown]
# # 03 - Evaluation and Explainability
#
# This notebook evaluates the saved best model and prepares outputs for report/demo.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT))
print(PROJECT_ROOT)

# %% [markdown]
# ## Evaluate from terminal

# %%
# !python -m src.evaluate --model-path models/best_exp2_resnet50_weighted_head.pth --architecture resnet50

# %%
from pathlib import Path
report_path = Path("outputs/classification_report.txt")
if report_path.exists():
    print(report_path.read_text())
else:
    print("Run evaluation first to create classification_report.txt")

# %%
from IPython.display import Image, display
for path in ["outputs/confusion_matrix.png", "outputs/training_curves_exp2_resnet50_weighted_head.png"]:
    if Path(path).exists():
        display(Image(path))
    else:
        print(f"Missing {path}")

# %% [markdown]
# ## Error analysis prompts
#
# Use `outputs/test_predictions.csv` to find:
#
# - best-performing classes
# - worst-performing classes
# - confusion pairs such as `mel` vs `nv` or `bkl`
# - low-confidence correct predictions
# - high-confidence wrong predictions

# %% [markdown]
# ## Grad-CAM
#
# The Streamlit demo can show Grad-CAM automatically for uploaded images. You can also call `src.gradcam.save_gradcam_example` for report images.
