# %% [markdown]
# # 02 - Training
#
# This notebook prepares train/validation/test splits and runs the advanced experiment plan.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT))
print(PROJECT_ROOT)

# %%
from src.dataset import prepare_dataframe, stratified_group_split, compute_class_weights

df = prepare_dataframe()
train_df, val_df, test_df = stratified_group_split(df)
print(train_df.shape, val_df.shape, test_df.shape)
print(train_df["dx"].value_counts())
print(compute_class_weights(train_df))

# %%
from src.dataset import make_loaders
train_loader, val_loader, test_loader = make_loaders(train_df, val_df, test_df, batch_size=32, num_workers=2)
images, labels = next(iter(train_loader))
print(images.shape, labels.shape)

# %% [markdown]
# ## Run one experiment
#
# Run this from the project root terminal:

# %%
# !python -m src.train --experiment-name exp2_resnet50_weighted_head --architecture resnet50 --freeze head --weighted-loss --epochs 8 --lr 1e-3

# %% [markdown]
# ## Run all advanced experiments

# %%
# !python -m src.run_experiments

# %% [markdown]
# ## Experiment plan
#
# 1. ResNet50, no class weights, head only.
# 2. ResNet50, weighted loss, head only.
# 3. ResNet50, weighted loss, last block fine-tuning.
# 4. ResNet50, weighted loss, whole model fine-tuning.
# 5. EfficientNet-B0, weighted loss, fine-tuning.
